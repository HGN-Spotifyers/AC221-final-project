# %%
import numpy as np
import pandas as pd

# %%
class Environment:
    
    def __init__(self):
        
        pass
    
    def assign_locations():
        
        self.locations = []

class Location:
    
    def __init__(self,environment):
        
        # Store simulation context:
        self.environment = environment
        
        # Simulate attributes attributes:
        self.assign_characteristics()
        self.assign_people()
        
    def assign_characteristics(self):
        
        # Demographic characteristics:
        self.name = None
        self.density = None
        self.popuation = None
        self.employment = None
        self.poverty = None
        self.phone_ownership = None
        
    def assign_people(self):
        
        self.people = []

class Person:
    
    def __init__(self,environment,location):
        
        # Store simulation context:
        self.environment = environment
        self.location = location
        
        # Simulate attributes:
        self.assign_demographics()
        self.assign_behavior()
        
    def assign_demographics(self):
        
        # Demographics:
        self.location = None  # Location ID
        self.poverty = None  # Boolean.
        self.phones = None  # 0, 1, 2.
        self.compliance = None  # Boolean.

    def assign_behavior(self):
        
        # Behavior profile:
        self.work_movement_profile = None
        self.social_movement_profile = None
        self.grocery_movement_profile = None
        # Average weekly distance:
        self.work_movement_distance = None
        self.social_movement_distance = None
        self.grocery_movement_distance = None
        # Percent change (between -1.0 and +inf):
        self.work_movement_change = None
        self.social_movement_change = None
        self.grocery_movement_change = None
        # Percent of distance captured by phone1:
        self.work_movement_captured = None
        self.social_movement_captured = None
        self.grocery_movement_captured = None
        ## Percent of distance captured by phone2:
        #self.work_movement_captured2 = None
        #self.social_movement_captured2 = None
        #self.grocery_movement_captured2 = None

# %%
profiles = pd.DataFrame([
    { 'density':'urban', '':'', },
])

# Behavior profile:
work_profile = None
social_profile = None
grocery_dprofile = None
# Average weekly distance:
work_distance = None
social_distance = None
grocery_distance = None
# Percent change (between -1.0 and +inf):
work_change = None
social_change = None
grocery_change = None
# Percent of distance captured by phone1:
work_captured = None
social_captured = None
grocery_captured = None

# %%
# Location attributes:
income_values = ['lo','hi']
density_values = ['lo','hi']
employment_values = ['lo','hi']

# Policy attributes:
enforcement_values = ['lo','hi']

# Behavior attributes:
work_movement_profiles = ['lo','hi']
social_movement_profiles = ['lo','hi']
grocery_movement_profiles = ['lo','hi']

# Conditional attributes:
phone_ownership_values = ['lo','hi']

# %%
# Random stuff:

location_profiles = pd.DataFrame([
    {'income' : 'lo', 'density' : 'lo', 'employment' : 'lo'},
    {'income' : 'lo', 'density' : 'lo', 'employment' : 'hi'},
    {'income' : 'lo', 'density' : 'hi', 'employment' : 'lo'},
    {'income' : 'lo', 'density' : 'hi', 'employment' : 'hi'},
    {'income' : 'hi', 'density' : 'lo', 'employment' : 'lo'},
    {'income' : 'hi', 'density' : 'lo', 'employment' : 'hi'},
    {'income' : 'hi', 'density' : 'hi', 'employment' : 'lo'},
    {'income' : 'hi', 'density' : 'hi', 'employment' : 'hi'},
])
location_profiles

location_profiles = pd.DataFrame([
    {'income' : 'lo', 'density' : 'lo', 'employment' : 'lo'},
    {'income' : 'lo', 'density' : 'lo', 'employment' : 'hi'},
    {'income' : 'lo', 'density' : 'hi', 'employment' : 'lo'},
    {'income' : 'lo', 'density' : 'hi', 'employment' : 'hi'},
    {'income' : 'hi', 'density' : 'lo', 'employment' : 'lo'},
    {'income' : 'hi', 'density' : 'lo', 'employment' : 'hi'},
    {'income' : 'hi', 'density' : 'hi', 'employment' : 'lo'},
    {'income' : 'hi', 'density' : 'hi', 'employment' : 'hi'},
])
location_profiles

locations = pd.DataFrame([
    { 'name':'loc1', 'density':'lo', 'popuation':4000, 'employment':0.7, 'poverty':0.3, 'phone_ownership':0.9 },
    { 'name':'loc2', 'density':'lo', 'popuation':4000, 'employment':0.6, 'poverty':0.6, 'phone_ownership':0.6 },
    { 'name':'loc3', 'density':'hi', 'popuation':2000, 'employment':0.6, 'poverty':0.5, 'phone_ownership':0.7 },
    { 'name':'loc4', 'density':'hi', 'popuation':2000, 'employment':0.7, 'poverty':0.5, 'phone_ownership':0.7 },
])
locations

# %%
np.random.seed(221)
